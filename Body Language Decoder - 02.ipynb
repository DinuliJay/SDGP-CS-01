# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (0.10.9)
# Requirement already satisfied: opencv-python in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (4.9.0.80)
# Requirement already satisfied: pandas in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (2.2.0)
# Requirement already satisfied: scikit-learn in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (1.4.0)
# Requirement already satisfied: absl-py in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\aqdha\appdata\roaming\python\python311\site-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (3.8.2)
# Requirement already satisfied: numpy in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (4.9.0.80)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aqdha\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\aqdha\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\aqdha\appdata\roaming\python\python311\site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\aqdha\appdata\roaming\python\python311\site-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aqdha\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: pycparser in c:\users\aqdha\appdata\roaming\python\python311\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)

# %%
import mediapipe as mp #Import Mediapipe
import cv2 #Import OpenCV

# %%
mp_drawing = mp.solutions.drawing_utils #To use the Drawing utilities
mp_holistic = mp.solutions.holistic #Media Pipe Models/Solutions

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()

        #Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Make Detection
        results = holistic.process(image) 

        #face_landmarks,pose_landmarks,left_hand_landmarks,right_hand_landmarks

        #Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        #Draw Face Landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(10,110,10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1,circle_radius=1)
                                 )
        
        
        # Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks
# Out:
# landmark {
#   x: 0.5815073
#   y: 0.68527246
#   z: -0.026331522
# }
# landmark {
#   x: 0.5864581
#   y: 0.6361222
#   z: -0.05892605
# }
# landmark {
#   x: 0.583022
#   y: 0.6491192
#   z: -0.028484173
# }
# landmark {
#   x: 0.5763175
#   y: 0.5821263
#   z: -0.049329758
# }
# landmark {
#   x: 0.58728385
#   y: 0.6204699
#   z: -0.063901804
# }
# landmark {
#   x: 0.5872073
#   y: 0.5987399
#   z: -0.061008167
# }
# landmark {
#   x: 0.5857535
#   y: 0.5450828
#   z: -0.03597807
# }
# landmark {
#   x: 0.49809995
#   y: 0.53498155
#   z: -0.00082017545
# }
# landmark {
#   x: 0.58606434
#   y: 0.50636256
#   z: -0.032678492
# }
# landmark {
#   x: 0.58693177
#   y: 0.48499867
#   z: -0.037271157
# }
# landmark {
#   x: 0.588079
#   y: 0.40588066
#   z: -0.032757625
# }
# landmark {
#   x: 0.5811227
#   y: 0.6928762
#   z: -0.024188757
# }
# landmark {
#   x: 0.58045197
#   y: 0.6984499
#   z: -0.01988699
# }
# landmark {
#   x: 0.57979316
#   y: 0.7004952
#   z: -0.014429253
# }
# landmark {
#   x: 0.5797708
#   y: 0.707629
#   z: -0.009745811
# }
# landmark {
#   x: 0.57971734
#   y: 0.71485215
#   z: -0.010947154
# }
# landmark {
#   x: 0.5794995
#   y: 0.7235998
#   z: -0.012410103
# }
# landmark {
#   x: 0.578916
#   y: 0.73252267
#   z: -0.009391103
# }
# landmark {
#   x: 0.57727015
#   y: 0.7448718
#   z: 0.00321298
# }
# landmark {
#   x: 0.5853809
#   y: 0.6432431
#   z: -0.052643865
# }
# landmark {
#   x: 0.5731769
#   y: 0.64037997
#   z: -0.037939504
# }
# landmark {
#   x: 0.45033357
#   y: 0.4667498
#   z: 0.041601382
# }
# landmark {
#   x: 0.5323403
#   y: 0.550331
#   z: -0.008436144
# }
# landmark {
#   x: 0.52064824
#   y: 0.5512714
#   z: -0.008667872
# }
# landmark {
#   x: 0.5090939
#   y: 0.5498581
#   z: -0.0066019697
# }
# landmark {
#   x: 0.49341136
#   y: 0.5396513
#   z: 0.0010774536
# }
# landmark {
#   x: 0.5421593
#   y: 0.5463578
#   z: -0.0063124583
# }
# landmark {
#   x: 0.51630646
#   y: 0.5121384
#   z: -0.01759082
# }
# landmark {
#   x: 0.52871263
#   y: 0.5134832
#   z: -0.01609366
# }
# landmark {
#   x: 0.5047172
#   y: 0.51348275
#   z: -0.014529842
# }
# landmark {
#   x: 0.49679425
#   y: 0.5175945
#   z: -0.009911716
# }
# landmark {
#   x: 0.4836064
#   y: 0.5487501
#   z: 0.00693898
# }
# landmark {
#   x: 0.53349763
#   y: 0.7630499
#   z: 0.014147158
# }
# landmark {
#   x: 0.49357623
#   y: 0.5306751
#   z: 0.002179899
# }
# landmark {
#   x: 0.44516224
#   y: 0.5347934
#   z: 0.052978046
# }
# landmark {
#   x: 0.46926287
#   y: 0.53592676
#   z: 0.016087584
# }
# landmark {
#   x: 0.52370447
#   y: 0.6146165
#   z: -0.012062015
# }
# landmark {
#   x: 0.567496
#   y: 0.68232083
#   z: -0.026309986
# }
# landmark {
#   x: 0.56872356
#   y: 0.6978208
#   z: -0.019604338
# }
# landmark {
#   x: 0.55255246
#   y: 0.6864949
#   z: -0.021085316
# }
# landmark {
#   x: 0.5433269
#   y: 0.6922685
#   z: -0.013818134
# }
# landmark {
#   x: 0.55817026
#   y: 0.6982218
#   z: -0.016669475
# }
# landmark {
#   x: 0.55019975
#   y: 0.6994358
#   z: -0.010003112
# }
# landmark {
#   x: 0.5270819
#   y: 0.713897
#   z: 0.005504741
# }
# landmark {
#   x: 0.57656777
#   y: 0.635085
#   z: -0.058795936
# }
# landmark {
#   x: 0.5757052
#   y: 0.6200011
#   z: -0.063476644
# }
# landmark {
#   x: 0.4771842
#   y: 0.49715266
#   z: -0.009697899
# }
# landmark {
#   x: 0.5471871
#   y: 0.57619226
#   z: -0.01596544
# }
# landmark {
#   x: 0.54596317
#   y: 0.6265908
#   z: -0.033831842
# }
# landmark {
#   x: 0.54496413
#   y: 0.61767167
#   z: -0.031077294
# }
# landmark {
#   x: 0.48867065
#   y: 0.6104674
#   z: -0.0018547911
# }
# landmark {
#   x: 0.57620806
#   y: 0.5997404
#   z: -0.058532767
# }
# landmark {
#   x: 0.50618297
#   y: 0.483824
#   z: -0.027894849
# }
# landmark {
#   x: 0.48921385
#   y: 0.48746625
#   z: -0.020197894
# }
# landmark {
#   x: 0.46333796
#   y: 0.44059598
#   z: 0.017711047
# }
# landmark {
#   x: 0.5598012
#   y: 0.5014013
#   z: -0.03191976
# }
# landmark {
#   x: 0.53973585
#   y: 0.5182512
#   z: -0.011304942
# }
# landmark {
#   x: 0.5191733
#   y: 0.6995398
#   z: 0.0055279876
# }
# landmark {
#   x: 0.45396483
#   y: 0.677224
#   z: 0.10064726
# }
# landmark {
#   x: 0.5543128
#   y: 0.6353893
#   z: -0.027930923
# }
# landmark {
#   x: 0.56417733
#   y: 0.6407477
#   z: -0.027115243
# }
# landmark {
#   x: 0.53277874
#   y: 0.7019326
#   z: 0.004423929
# }
# landmark {
#   x: 0.5383151
#   y: 0.70101225
#   z: 0.0018042759
# }
# landmark {
#   x: 0.48190176
#   y: 0.4751674
#   z: -0.01632689
# }
# landmark {
#   x: 0.5449607
#   y: 0.6326606
#   z: -0.026863178
# }
# landmark {
#   x: 0.52931964
#   y: 0.48740527
#   z: -0.032136094
# }
# landmark {
#   x: 0.52740085
#   y: 0.4735214
#   z: -0.035884112
# }
# landmark {
#   x: 0.51598316
#   y: 0.4089149
#   z: -0.024475103
# }
# landmark {
#   x: 0.47288257
#   y: 0.457517
#   z: -0.0020886224
# }
# landmark {
#   x: 0.5231227
#   y: 0.44052225
#   z: -0.031053597
# }
# landmark {
#   x: 0.4693048
#   y: 0.4884481
#   z: -0.0013817705
# }
# landmark {
#   x: 0.45997292
#   y: 0.47851723
#   z: 0.018514775
# }
# landmark {
#   x: 0.5679459
#   y: 0.69147193
#   z: -0.02438337
# }
# landmark {
#   x: 0.5558143
#   y: 0.69385713
#   z: -0.019347062
# }
# landmark {
#   x: 0.54690665
#   y: 0.69632107
#   z: -0.01286134
# }
# landmark {
#   x: 0.5571538
#   y: 0.6380825
#   z: -0.024876362
# }
# landmark {
#   x: 0.53574973
#   y: 0.70188534
#   z: 0.0029814667
# }
# landmark {
#   x: 0.54004467
#   y: 0.7052629
#   z: -0.0020381203
# }
# landmark {
#   x: 0.53929484
#   y: 0.69983274
#   z: 0.0015552121
# }
# landmark {
#   x: 0.5620163
#   y: 0.6321177
#   z: -0.04408054
# }
# landmark {
#   x: 0.5522041
#   y: 0.6982961
#   z: -0.007861349
# }
# landmark {
#   x: 0.56011194
#   y: 0.69869155
#   z: -0.011827686
# }
# landmark {
#   x: 0.56963855
#   y: 0.6995789
#   z: -0.014504084
# }
# landmark {
#   x: 0.56245303
#   y: 0.7432488
#   z: 0.001962323
# }
# landmark {
#   x: 0.56482977
#   y: 0.7304174
#   z: -0.010465595
# }
# landmark {
#   x: 0.5663041
#   y: 0.72135496
#   z: -0.013040634
# }
# landmark {
#   x: 0.5676678
#   y: 0.71247566
#   z: -0.011414373
# }
# landmark {
#   x: 0.568707
#   y: 0.7066464
#   z: -0.010083888
# }
# landmark {
#   x: 0.5505198
#   y: 0.70345026
#   z: -0.0049872487
# }
# landmark {
#   x: 0.5486685
#   y: 0.7056399
#   z: -0.0064879837
# }
# landmark {
#   x: 0.5457274
#   y: 0.70991665
#   z: -0.007692558
# }
# landmark {
#   x: 0.5429376
#   y: 0.7148186
#   z: -0.005646502
# }
# landmark {
#   x: 0.53332305
#   y: 0.67334366
#   z: -0.012136582
# }
# landmark {
#   x: 0.44198292
#   y: 0.5997657
#   z: 0.107845396
# }
# landmark {
#   x: 0.5842607
#   y: 0.64529717
#   z: -0.037135802
# }
# landmark {
#   x: 0.5451922
#   y: 0.70219105
#   z: -0.0012697132
# }
# landmark {
#   x: 0.54302984
#   y: 0.7032381
#   z: -0.0021181835
# }
# landmark {
#   x: 0.56807554
#   y: 0.6479895
#   z: -0.026705975
# }
# landmark {
#   x: 0.54859287
#   y: 0.6418805
#   z: -0.016901594
# }
# landmark {
#   x: 0.5662178
#   y: 0.6445593
#   z: -0.02723686
# }
# landmark {
#   x: 0.53477705
#   y: 0.5845147
#   z: -0.012164347
# }
# landmark {
#   x: 0.5160613
#   y: 0.59419763
#   z: -0.009498303
# }
# landmark {
#   x: 0.542545
#   y: 0.62389356
#   z: -0.024172086
# }
# landmark {
#   x: 0.48409054
#   y: 0.420588
#   z: -0.0056521846
# }
# landmark {
#   x: 0.49280688
#   y: 0.44374222
#   z: -0.018115556
# }
# landmark {
#   x: 0.50171465
#   y: 0.46955585
#   z: -0.027652912
# }
# landmark {
#   x: 0.5361347
#   y: 0.7244878
#   z: 0.0026732937
# }
# landmark {
#   x: 0.55669385
#   y: 0.47997206
#   z: -0.038571272
# }
# landmark {
#   x: 0.55375046
#   y: 0.44255418
#   z: -0.03693742
# }
# landmark {
#   x: 0.5496831
#   y: 0.40483963
#   z: -0.033300836
# }
# landmark {
#   x: 0.49914274
#   y: 0.54612553
#   z: -0.0026689905
# }
# landmark {
#   x: 0.47060367
#   y: 0.55867434
#   z: 0.013106522
# }
# landmark {
#   x: 0.5483669
#   y: 0.5425015
#   z: -0.0047448943
# }
# landmark {
#   x: 0.4829951
#   y: 0.5191175
#   z: -0.0009798029
# }
# landmark {
#   x: 0.55605704
#   y: 0.56690013
#   z: -0.020170325
# }
# landmark {
#   x: 0.5544565
#   y: 0.62238634
#   z: -0.044861782
# }
# landmark {
#   x: 0.4573026
#   y: 0.56765634
#   z: 0.02548542
# }
# landmark {
#   x: 0.47954154
#   y: 0.5710651
#   z: 0.0046138573
# }
# landmark {
#   x: 0.49534577
#   y: 0.578362
#   z: -0.003747047
# }
# landmark {
#   x: 0.5178232
#   y: 0.57712483
#   z: -0.006928488
# }
# landmark {
#   x: 0.5341618
#   y: 0.5711346
#   z: -0.008398136
# }
# landmark {
#   x: 0.54647964
#   y: 0.56436974
#   z: -0.010972845
# }
# landmark {
#   x: 0.5739043
#   y: 0.5483984
#   z: -0.032590788
# }
# landmark {
#   x: 0.45970628
#   y: 0.60096616
#   z: 0.025698677
# }
# landmark {
#   x: 0.47251278
#   y: 0.5146725
#   z: 0.002969497
# }
# landmark {
#   x: 0.5793497
#   y: 0.6423556
#   z: -0.05264195
# }
# landmark {
#   x: 0.5482681
#   y: 0.5921878
#   z: -0.018908143
# }
# landmark {
#   x: 0.43969354
#   y: 0.5305111
#   z: 0.09064746
# }
# landmark {
#   x: 0.55604184
#   y: 0.5567391
#   z: -0.0127856545
# }
# landmark {
#   x: 0.5410214
#   y: 0.62392676
#   z: -0.012526328
# }
# landmark {
#   x: 0.4894566
#   y: 0.5305501
#   z: 0.004073095
# }
# landmark {
#   x: 0.55353516
#   y: 0.6114902
#   z: -0.041353233
# }
# landmark {
#   x: 0.44534114
#   y: 0.6372816
#   z: 0.107223995
# }
# landmark {
#   x: 0.54783815
#   y: 0.53685546
#   z: -0.0029073562
# }
# landmark {
#   x: 0.5648082
#   y: 0.6040915
#   z: -0.052224323
# }
# landmark {
#   x: 0.4820584
#   y: 0.72137547
#   z: 0.046579327
# }
# landmark {
#   x: 0.4801723
#   y: 0.736359
#   z: 0.06876818
# }
# landmark {
#   x: 0.44560406
#   y: 0.6011918
#   z: 0.06600201
# }
# landmark {
#   x: 0.46797743
#   y: 0.6980366
#   z: 0.057081383
# }
# landmark {
#   x: 0.45229903
#   y: 0.5042302
#   z: 0.03853724
# }
# landmark {
#   x: 0.529309
#   y: 0.77877533
#   z: 0.022548568
# }
# landmark {
#   x: 0.5796269
#   y: 0.64441234
#   z: -0.036765944
# }
# landmark {
#   x: 0.53744113
#   y: 0.6028863
#   z: -0.014352573
# }
# landmark {
#   x: 0.45838636
#   y: 0.53729093
#   z: 0.026492009
# }
# landmark {
#   x: 0.5103063
#   y: 0.54112893
#   z: -0.0062412573
# }
# landmark {
#   x: 0.5207447
#   y: 0.54300755
#   z: -0.00824686
# }
# landmark {
#   x: 0.5367874
#   y: 0.7077735
#   z: -0.00027312012
# }
# landmark {
#   x: 0.46159098
#   y: 0.6319511
#   z: 0.03324504
# }
# landmark {
#   x: 0.5487646
#   y: 0.80178714
#   z: 0.030327747
# }
# landmark {
#   x: 0.5128934
#   y: 0.7764309
#   z: 0.04559319
# }
# landmark {
#   x: 0.4974685
#   y: 0.75977576
#   z: 0.05536068
# }
# landmark {
#   x: 0.58771324
#   y: 0.44518888
#   z: -0.03621919
# }
# landmark {
#   x: 0.57321763
#   y: 0.8055111
#   z: 0.02995133
# }
# landmark {
#   x: 0.5305442
#   y: 0.54206973
#   z: -0.007882212
# }
# landmark {
#   x: 0.5396648
#   y: 0.53949654
#   z: -0.0057223914
# }
# landmark {
#   x: 0.54521996
#   y: 0.53802156
#   z: -0.003235712
# }
# landmark {
#   x: 0.4631735
#   y: 0.509685
#   z: 0.0133467
# }
# landmark {
#   x: 0.53769845
#   y: 0.5276432
#   z: -0.009126627
# }
# landmark {
#   x: 0.52739894
#   y: 0.5243921
#   z: -0.0122564575
# }
# landmark {
#   x: 0.5174151
#   y: 0.5235795
#   z: -0.01257545
# }
# landmark {
#   x: 0.50735873
#   y: 0.52511114
#   z: -0.010296094
# }
# landmark {
#   x: 0.5008024
#   y: 0.5276714
#   z: -0.0067364024
# }
# landmark {
#   x: 0.44307446
#   y: 0.4948085
#   z: 0.068224825
# }
# landmark {
#   x: 0.50317305
#   y: 0.5380965
#   z: -0.0033950305
# }
# landmark {
#   x: 0.5823703
#   y: 0.66016376
#   z: -0.025005378
# }
# landmark {
#   x: 0.5433825
#   y: 0.66459215
#   z: -0.017247776
# }
# landmark {
#   x: 0.5544668
#   y: 0.6333513
#   z: -0.032544464
# }
# landmark {
#   x: 0.5663553
#   y: 0.6609228
#   z: -0.02534157
# }
# landmark {
#   x: 0.585374
#   y: 0.5250504
#   z: -0.030056927
# }
# landmark {
#   x: 0.49714673
#   y: 0.74367976
#   z: 0.039332796
# }
# landmark {
#   x: 0.5125
#   y: 0.76132953
#   z: 0.03169549
# }
# landmark {
#   x: 0.55002314
#   y: 0.7912915
#   z: 0.015066577
# }
# landmark {
#   x: 0.46630588
#   y: 0.71055055
#   z: 0.08571446
# }
# landmark {
#   x: 0.5448055
#   y: 0.53299344
#   z: -0.005546756
# }
# landmark {
#   x: 0.5655576
#   y: 0.5731638
#   z: -0.03431867
# }
# landmark {
#   x: 0.5747594
#   y: 0.79519886
#   z: 0.015243794
# }
# landmark {
#   x: 0.52959704
#   y: 0.7912283
#   z: 0.035593513
# }
# landmark {
#   x: 0.44924524
#   y: 0.635484
#   z: 0.06864237
# }
# landmark {
#   x: 0.5587829
#   y: 0.7048934
#   z: -0.008030819
# }
# landmark {
#   x: 0.5569718
#   y: 0.7091622
#   z: -0.0097050965
# }
# landmark {
#   x: 0.5546784
#   y: 0.7157964
#   z: -0.011043236
# }
# landmark {
#   x: 0.55250305
#   y: 0.72390896
#   z: -0.009079779
# }
# landmark {
#   x: 0.54760027
#   y: 0.7351187
#   z: 0.00049238146
# }
# landmark {
#   x: 0.5432466
#   y: 0.70025027
#   z: -0.004178846
# }
# landmark {
#   x: 0.53979033
#   y: 0.6992195
#   z: -0.004790647
# }
# landmark {
#   x: 0.53628397
#   y: 0.6967356
#   z: -0.005294719
# }
# landmark {
#   x: 0.5246724
#   y: 0.68547
#   z: -0.0044061965
# }
# landmark {
#   x: 0.4787326
#   y: 0.6424304
#   z: 0.012816197
# }
# landmark {
#   x: 0.5651543
#   y: 0.5566201
#   z: -0.025635716
# }
# landmark {
#   x: 0.5579758
#   y: 0.5266111
#   z: -0.010729891
# }
# landmark {
#   x: 0.55019426
#   y: 0.52871966
#   z: -0.007440506
# }
# landmark {
#   x: 0.5455586
#   y: 0.6980215
#   z: -0.002772443
# }
# landmark {
#   x: 0.47539482
#   y: 0.678361
#   z: 0.03370633
# }
# landmark {
#   x: 0.56929415
#   y: 0.5266454
#   z: -0.023931352
# }
# landmark {
#   x: 0.5402929
#   y: 0.748077
#   z: 0.00812755
# }
# landmark {
#   x: 0.58666676
#   y: 0.58028793
#   z: -0.052084234
# }
# landmark {
#   x: 0.5749
#   y: 0.5660379
#   z: -0.042093437
# }
# landmark {
#   x: 0.5861691
#   y: 0.5632997
#   z: -0.043809302
# }
# landmark {
#   x: 0.55646074
#   y: 0.5972278
#   z: -0.0325154
# }
# landmark {
#   x: 0.57582855
#   y: 0.77928674
#   z: 0.007441202
# }
# landmark {
#   x: 0.5765503
#   y: 0.76049083
#   z: 0.0055066273
# }
# landmark {
#   x: 0.5582273
#   y: 0.758134
#   z: 0.0057545383
# }
# landmark {
#   x: 0.514316
#   y: 0.7181909
#   z: 0.012661247
# }
# landmark {
#   x: 0.5314597
#   y: 0.63584083
#   z: -0.009905542
# }
# landmark {
#   x: 0.5258405
#   y: 0.7348223
#   z: 0.010862814
# }
# landmark {
#   x: 0.5054349
#   y: 0.632071
#   z: -0.007299399
# }
# landmark {
#   x: 0.5210638
#   y: 0.6512083
#   z: -0.0079088025
# }
# landmark {
#   x: 0.494829
#   y: 0.65626377
#   z: 0.002875718
# }
# landmark {
#   x: 0.5533762
#   y: 0.7757682
#   z: 0.0076759104
# }
# landmark {
#   x: 0.54838663
#   y: 0.6048214
#   z: -0.024160275
# }
# landmark {
#   x: 0.5026694
#   y: 0.7280687
#   z: 0.024446905
# }
# landmark {
#   x: 0.5178087
#   y: 0.7465241
#   z: 0.021247001
# }
# landmark {
#   x: 0.5061196
#   y: 0.69898117
#   z: 0.010712696
# }
# landmark {
#   x: 0.46401706
#   y: 0.65803045
#   z: 0.040756565
# }
# landmark {
#   x: 0.49012643
#   y: 0.6982744
#   z: 0.021503521
# }
# landmark {
#   x: 0.45549765
#   y: 0.66745734
#   z: 0.06792554
# }
# landmark {
#   x: 0.51189536
#   y: 0.6715605
#   z: -0.002012776
# }
# landmark {
#   x: 0.5569676
#   y: 0.5823708
#   z: -0.026084606
# }
# landmark {
#   x: 0.5583825
#   y: 0.6296605
#   z: -0.046770662
# }
# landmark {
#   x: 0.5495836
#   y: 0.63198286
#   z: -0.03426906
# }
# landmark {
#   x: 0.56468344
#   y: 0.6205795
#   z: -0.054916386
# }
# landmark {
#   x: 0.54868877
#   y: 0.51351756
#   z: -0.01655465
# }
# landmark {
#   x: 0.5294112
#   y: 0.5044897
#   z: -0.02088719
# }
# landmark {
#   x: 0.51283735
#   y: 0.50184625
#   z: -0.021444563
# }
# landmark {
#   x: 0.49880245
#   y: 0.5029057
#   z: -0.017662177
# }
# landmark {
#   x: 0.48866338
#   y: 0.5083465
#   z: -0.010904196
# }
# landmark {
#   x: 0.4807397
#   y: 0.53317857
#   z: 0.008306005
# }
# landmark {
#   x: 0.44370496
#   y: 0.5677578
#   z: 0.05978972
# }
# landmark {
#   x: 0.49053186
#   y: 0.5564148
#   z: 0.0022541126
# }
# landmark {
#   x: 0.50286937
#   y: 0.5620511
#   z: -0.0030792032
# }
# landmark {
#   x: 0.51867765
#   y: 0.56290495
#   z: -0.0062955637
# }
# landmark {
#   x: 0.53346395
#   y: 0.5597697
#   z: -0.0072657405
# }
# landmark {
#   x: 0.54496205
#   y: 0.5548224
#   z: -0.006923076
# }
# landmark {
#   x: 0.55297697
#   y: 0.5501187
#   z: -0.007464424
# }
# landmark {
#   x: 0.4405592
#   y: 0.5648619
#   z: 0.10274947
# }
# landmark {
#   x: 0.549499
#   y: 0.63549125
#   z: -0.028208025
# }
# landmark {
#   x: 0.5661284
#   y: 0.58827215
#   z: -0.04169542
# }
# landmark {
#   x: 0.5677422
#   y: 0.6318552
#   z: -0.054451242
# }
# landmark {
#   x: 0.5731635
#   y: 0.6388904
#   z: -0.048512906
# }
# landmark {
#   x: 0.5670373
#   y: 0.6336606
#   z: -0.048813164
# }
# landmark {
#   x: 0.5525695
#   y: 0.6399861
#   z: -0.023359569
# }
# landmark {
#   x: 0.5755546
#   y: 0.64084643
#   z: -0.05124201
# }
# landmark {
#   x: 0.5757354
#   y: 0.643059
#   z: -0.037330832
# }
# landmark {
#   x: 0.5523797
#   y: 0.5379858
#   z: -0.0037175629
# }
# landmark {
#   x: 0.5593933
#   y: 0.5421083
#   z: -0.00933677
# }
# landmark {
#   x: 0.5635811
#   y: 0.54518217
#   z: -0.016226474
# }
# landmark {
#   x: 0.49681386
#   y: 0.52940816
#   z: -0.0028739474
# }
# landmark {
#   x: 0.4904307
#   y: 0.5221101
#   z: -0.0031484773
# }
# landmark {
#   x: 0.5960345
#   y: 0.5829038
#   z: -0.046884213
# }
# landmark {
#   x: 0.6608896
#   y: 0.54124683
#   z: 0.016850555
# }
# landmark {
#   x: 0.59466296
#   y: 0.64106864
#   z: -0.036030702
# }
# landmark {
#   x: 0.6976259
#   y: 0.47807884
#   z: 0.068771064
# }
# landmark {
#   x: 0.62827635
#   y: 0.55402267
#   z: 0.002902897
# }
# landmark {
#   x: 0.6393657
#   y: 0.5558851
#   z: 0.004975028
# }
# landmark {
#   x: 0.6499858
#   y: 0.5551758
#   z: 0.009128271
# }
# landmark {
#   x: 0.66365767
#   y: 0.5461277
#   z: 0.01973838
# }
# landmark {
#   x: 0.6193058
#   y: 0.5494689
#   z: 0.0025464382
# }
# landmark {
#   x: 0.646572
#   y: 0.51821923
#   z: -0.0031855162
# }
# landmark {
#   x: 0.6347238
#   y: 0.5186259
#   z: -0.0048008524
# }
# landmark {
#   x: 0.6571034
#   y: 0.5202025
#   z: 0.0021815256
# }
# landmark {
#   x: 0.66353697
#   y: 0.52485096
#   z: 0.007989915
# }
# landmark {
#   x: 0.67109007
#   y: 0.55572575
#   z: 0.026924457
# }
# landmark {
#   x: 0.6149671
#   y: 0.7639647
#   z: 0.022151805
# }
# landmark {
#   x: 0.6645923
#   y: 0.53737015
#   z: 0.020701982
# }
# landmark {
#   x: 0.697626
#   y: 0.5446641
#   z: 0.08043318
# }
# landmark {
#   x: 0.6828915
#   y: 0.5440842
#   z: 0.038617764
# }
# landmark {
#   x: 0.6354366
#   y: 0.6182893
#   z: -0.00071585487
# }
# landmark {
#   x: 0.5949828
#   y: 0.68310946
#   z: -0.023366587
# }
# landmark {
#   x: 0.59122014
#   y: 0.698434
#   z: -0.016933013
# }
# landmark {
#   x: 0.6075102
#   y: 0.6879419
#   z: -0.015005737
# }
# landmark {
#   x: 0.6141161
#   y: 0.69417435
#   z: -0.005578721
# }
# landmark {
#   x: 0.6000801
#   y: 0.6993688
#   z: -0.0115072215
# }
# landmark {
#   x: 0.6063498
#   y: 0.7010947
#   z: -0.0031697203
# }
# landmark {
#   x: 0.6244937
#   y: 0.71624744
#   z: 0.016024282
# }
# landmark {
#   x: 0.5957523
#   y: 0.635717
#   z: -0.057155397
# }
# landmark {
#   x: 0.59800124
#   y: 0.6208096
#   z: -0.061586063
# }
# landmark {
#   x: 0.6824102
#   y: 0.5059266
#   z: 0.01163787
# }
# landmark {
#   x: 0.6155571
#   y: 0.57874924
#   z: -0.008461151
# }
# landmark {
#   x: 0.61911744
#   y: 0.6289444
#   z: -0.026701398
# }
# landmark {
#   x: 0.6194519
#   y: 0.6200885
#   z: -0.023743767
# }
# landmark {
#   x: 0.6650843
#   y: 0.61603564
#   z: 0.01686611
# }
# landmark {
#   x: 0.59728324
#   y: 0.60049814
#   z: -0.05614487
# }
# landmark {
#   x: 0.660733
#   y: 0.4915624
#   z: -0.01311617
# }
# landmark {
#   x: 0.6744353
#   y: 0.4960072
#   z: -0.0017574251
# }
# landmark {
#   x: 0.6919919
#   y: 0.4517094
#   z: 0.042081427
# }
# landmark {
#   x: 0.61103076
#   y: 0.50423336
#   z: -0.027011773
# }
# landmark {
#   x: 0.6237995
#   y: 0.52241886
#   z: -0.002039342
# }
# landmark {
#   x: 0.632877
#   y: 0.70256406
#   z: 0.018318206
# }
# landmark {
#   x: 0.6744251
#   y: 0.68227136
#   z: 0.12556052
# }
# landmark {
#   x: 0.61043185
#   y: 0.6371119
#   z: -0.022662649
# }
# landmark {
#   x: 0.6010482
#   y: 0.6420001
#   z: -0.024427408
# }
# landmark {
#   x: 0.6204383
#   y: 0.7045211
#   z: 0.015414903
# }
# landmark {
#   x: 0.61509067
#   y: 0.7033732
#   z: 0.011399683
# }
# landmark {
#   x: 0.6809892
#   y: 0.4844456
#   z: 0.003547104
# }
# landmark {
#   x: 0.6183166
#   y: 0.6349778
#   z: -0.01993635
# }
# landmark {
#   x: 0.64025223
#   y: 0.49321294
#   z: -0.021933831
# }
# landmark {
#   x: 0.643395
#   y: 0.47958738
#   z: -0.025285836
# }
# landmark {
#   x: 0.6538167
#   y: 0.41638878
#   z: -0.010445755
# }
# landmark {
#   x: 0.6866958
#   y: 0.46754426
#   z: 0.019832669
# }
# landmark {
#   x: 0.6478424
#   y: 0.4471945
#   z: -0.01886559
# }
# landmark {
#   x: 0.6884798
#   y: 0.4977695
#   z: 0.021445272
# }
# landmark {
#   x: 0.6933086
#   y: 0.48880708
#   z: 0.043226212
# }
# landmark {
#   x: 0.5934102
#   y: 0.69219697
#   z: -0.021531617
# }
# landmark {
#   x: 0.60356486
#   y: 0.6950948
#   z: -0.013780766
# }
# landmark {
#   x: 0.61035514
#   y: 0.69805986
#   z: -0.005391827
# }
# landmark {
#   x: 0.6072243
#   y: 0.63968337
#   z: -0.02059581
# }
# landmark {
#   x: 0.617704
#   y: 0.70428413
#   z: 0.013131283
# }
# landmark {
#   x: 0.61419594
#   y: 0.707399
#   z: 0.0065040407
# }
# landmark {
#   x: 0.61385894
#   y: 0.7019737
#   z: 0.010892771
# }
# landmark {
#   x: 0.60614914
#   y: 0.6333815
#   z: -0.03922243
# }
# landmark {
#   x: 0.6034895
#   y: 0.6998864
#   z: -0.001369846
# }
# landmark {
#   x: 0.597068
#   y: 0.6998648
#   z: -0.007036266
# }
# landmark {
#   x: 0.5890148
#   y: 0.70021796
#   z: -0.011838863
# }
# landmark {
#   x: 0.59126
#   y: 0.74378216
#   z: 0.00460215
# }
# landmark {
#   x: 0.592111
#   y: 0.7310237
#   z: -0.007844592
# }
# landmark {
#   x: 0.59186137
#   y: 0.72195333
#   z: -0.010270911
# }
# landmark {
#   x: 0.5910469
#   y: 0.71317047
#   z: -0.008597219
# }
# landmark {
#   x: 0.589953
#   y: 0.70721126
#   z: -0.0073623247
# }
# landmark {
#   x: 0.6050872
#   y: 0.7049817
#   z: 0.0014852356
# }
# landmark {
#   x: 0.6069622
#   y: 0.70727015
#   z: 3.6150552e-06
# }
# landmark {
#   x: 0.60960096
#   y: 0.7116266
#   z: -0.0010589584
# }
# landmark {
#   x: 0.6118598
#   y: 0.71657777
#   z: 0.0015705631
# }
# landmark {
#   x: 0.6245233
#   y: 0.675913
#   z: -0.0025628586
# }
# landmark {
#   x: 0.6883532
#   y: 0.6079463
#   z: 0.13570246
# }
# landmark {
#   x: 0.60899574
#   y: 0.70410466
#   z: 0.0069196327
# }
# landmark {
#   x: 0.61141145
#   y: 0.7053251
#   z: 0.006079616
# }
# landmark {
#   x: 0.5970838
#   y: 0.64896834
#   z: -0.024081055
# }
# landmark {
#   x: 0.6134266
#   y: 0.6439793
#   z: -0.011451595
# }
# landmark {
#   x: 0.5990077
#   y: 0.6456583
#   z: -0.024660772
# }
# landmark {
#   x: 0.6259831
#   y: 0.58778894
#   z: -0.0022575264
# }
# landmark {
#   x: 0.6426212
#   y: 0.59858155
#   z: 0.0038523907
# }
# landmark {
#   x: 0.6202571
#   y: 0.626339
#   z: -0.016640842
# }
# landmark {
#   x: 0.67860156
#   y: 0.43059805
#   z: 0.0142333275
# }
# landmark {
#   x: 0.67275995
#   y: 0.45273614
#   z: -0.00047636192
# }
# landmark {
#   x: 0.66564894
#   y: 0.47777545
#   z: -0.011914565
# }
# landmark {
#   x: 0.6160143
#   y: 0.7262105
#   z: 0.011168165
# }
# landmark {
#   x: 0.61620396
#   y: 0.48350126
#   z: -0.033314254
# }
# landmark {
#   x: 0.62026435
#   y: 0.4461912
#   z: -0.030570948
# }
# landmark {
#   x: 0.6244815
#   y: 0.4090287
#   z: -0.02631315
# }
# landmark {
#   x: 0.6586944
#   y: 0.55212003
#   z: 0.014981795
# }
# landmark {
#   x: 0.6811154
#   y: 0.5662695
#   z: 0.03534531
# }
# landmark {
#   x: 0.61397547
#   y: 0.54515207
#   z: 0.0032205675
# }
# landmark {
#   x: 0.6744535
#   y: 0.52694714
#   z: 0.019498356
# }
# landmark {
#   x: 0.608757
#   y: 0.56890196
#   z: -0.01413675
# }
# landmark {
#   x: 0.6136318
#   y: 0.6243556
#   z: -0.039084014
# }
# landmark {
#   x: 0.6901346
#   y: 0.57586217
#   z: 0.050678488
# }
# landmark {
#   x: 0.6741009
#   y: 0.5779468
#   z: 0.025499288
# }
# landmark {
#   x: 0.6609931
#   y: 0.58412117
#   z: 0.013888389
# }
# landmark {
#   x: 0.6410078
#   y: 0.581496
#   z: 0.006574521
# }
# landmark {
#   x: 0.6263072
#   y: 0.574547
#   z: 0.0018252053
# }
# landmark {
#   x: 0.6156023
#   y: 0.56701
#   z: -0.0032101502
# }
# landmark {
#   x: 0.5961322
#   y: 0.5493211
#   z: -0.030043382
# }
# landmark {
#   x: 0.6865787
#   y: 0.6082164
#   z: 0.050673407
# }
# landmark {
#   x: 0.6831459
#   y: 0.5231983
#   z: 0.025479034
# }
# landmark {
#   x: 0.5910279
#   y: 0.642681
#   z: -0.05128962
# }
# landmark {
#   x: 0.6148373
#   y: 0.59459305
#   z: -0.0116418805
# }
# landmark {
#   x: 0.6963505
#   y: 0.54096895
#   z: 0.119511105
# }
# landmark {
#   x: 0.6078769
#   y: 0.5587745
#   z: -0.006700551
# }
# landmark {
#   x: 0.6199622
#   y: 0.6264939
#   z: -0.0051608817
# }
# landmark {
#   x: 0.6675974
#   y: 0.53757524
#   z: 0.02344236
# }
# landmark {
#   x: 0.61370444
#   y: 0.6135485
#   z: -0.035491876
# }
# landmark {
#   x: 0.68342
#   y: 0.6440521
#   z: 0.13395609
# }
# landmark {
#   x: 0.6144272
#   y: 0.5396325
#   z: 0.0055020293
# }
# landmark {
#   x: 0.6059373
#   y: 0.6054709
#   z: -0.04803422
# }
# landmark {
#   x: 0.6573218
#   y: 0.7243274
#   z: 0.06507544
# }
# landmark {
#   x: 0.65394986
#   y: 0.7388209
#   z: 0.08758963
# }
# landmark {
#   x: 0.6926065
#   y: 0.6090331
#   z: 0.09336449
# }
# landmark {
#   x: 0.6688235
#   y: 0.70219487
#   z: 0.07889445
# }
# landmark {
#   x: 0.6955907
#   y: 0.5143507
#   z: 0.06493109
# }
# landmark {
#   x: 0.6169271
#   y: 0.7794102
#   z: 0.031279318
# }
# landmark {
#   x: 0.5888101
#   y: 0.6447462
#   z: -0.03602097
# }
# landmark {
#   x: 0.62334067
#   y: 0.6057951
#   z: -0.0054722307
# }
# landmark {
#   x: 0.69046485
#   y: 0.5461444
#   z: 0.05135429
# }
# landmark {
#   x: 0.6501024
#   y: 0.54660326
#   z: 0.009231732
# }
# landmark {
#   x: 0.64021075
#   y: 0.54774535
#   z: 0.005519624
# }
# landmark {
#   x: 0.61685276
#   y: 0.7099912
#   z: 0.008877087
# }
# landmark {
#   x: 0.68213326
#   y: 0.63822484
#   z: 0.057230882
# }
# landmark {
#   x: 0.5967142
#   y: 0.8019607
#   z: 0.03517888
# }
# landmark {
#   x: 0.62769943
#   y: 0.7772001
#   z: 0.057836466
# }
# landmark {
#   x: 0.6401525
#   y: 0.76106596
#   z: 0.07072457
# }
# landmark {
#   x: 0.63065803
#   y: 0.54618454
#   z: 0.0038358516
# }
# landmark {
#   x: 0.6220072
#   y: 0.5428051
#   z: 0.004242065
# }
# landmark {
#   x: 0.6168477
#   y: 0.540933
#   z: 0.005793505
# }
# landmark {
#   x: 0.68988967
#   y: 0.5189116
#   z: 0.037501384
# }
# landmark {
#   x: 0.62433565
#   y: 0.53141487
#   z: 0.0012182024
# }
# landmark {
#   x: 0.6341679
#   y: 0.52905935
#   z: -0.00034416065
# }
# landmark {
#   x: 0.64395833
#   y: 0.5289281
#   z: 0.0014379779
# }
# landmark {
#   x: 0.65339744
#   y: 0.53101087
#   z: 0.0055263075
# }
# landmark {
#   x: 0.65905225
#   y: 0.5339605
#   z: 0.010217263
# }
# landmark {
#   x: 0.69891727
#   y: 0.50599694
#   z: 0.0966416
# }
# landmark {
#   x: 0.65658724
#   y: 0.5440123
#   z: 0.013439185
# }
# landmark {
#   x: 0.6168679
#   y: 0.6667024
#   z: -0.009986153
# }
# landmark {
#   x: 0.611232
#   y: 0.6351087
#   z: -0.027508445
# }
# landmark {
#   x: 0.59747076
#   y: 0.661863
#   z: -0.022267886
# }
# landmark {
#   x: 0.6443636
#   y: 0.7454689
#   z: 0.054319996
# }
# landmark {
#   x: 0.6311453
#   y: 0.76242757
#   z: 0.04354451
# }
# landmark {
#   x: 0.59835094
#   y: 0.7916159
#   z: 0.019824341
# }
# landmark {
#   x: 0.66430444
#   y: 0.7143088
#   z: 0.108104534
# }
# landmark {
#   x: 0.6175846
#   y: 0.5359743
#   z: 0.0036602004
# }
# landmark {
#   x: 0.60304344
#   y: 0.57454497
#   z: -0.030207597
# }
# landmark {
#   x: 0.61388826
#   y: 0.79165316
#   z: 0.04452321
# }
# landmark {
#   x: 0.6868759
#   y: 0.64209694
#   z: 0.09474486
# }
# landmark {
#   x: 0.5985144
#   y: 0.70602864
#   z: -0.0032763141
# }
# landmark {
#   x: 0.60026306
#   y: 0.7103193
#   z: -0.0046987967
# }
# landmark {
#   x: 0.6021317
#   y: 0.71701896
#   z: -0.005962976
# }
# landmark {
#   x: 0.6034634
#   y: 0.7251209
#   z: -0.0036409383
# }
# landmark {
#   x: 0.6052386
#   y: 0.73628664
#   z: 0.006546147
# }
# landmark {
#   x: 0.6114386
#   y: 0.7022634
#   z: 0.004447433
# }
# landmark {
#   x: 0.6151712
#   y: 0.7014815
#   z: 0.004673732
# }
# landmark {
#   x: 0.61865544
#   y: 0.69919217
#   z: 0.0048078927
# }
# landmark {
#   x: 0.63034904
#   y: 0.68841773
#   z: 0.007406324
# }
# landmark {
#   x: 0.66964966
#   y: 0.6478729
#   z: 0.03302241
# }
# landmark {
#   x: 0.6023261
#   y: 0.5581363
#   z: -0.021392992
# }
# landmark {
#   x: 0.6073303
#   y: 0.5288488
#   z: -0.0052452427
# }
# landmark {
#   x: 0.6132823
#   y: 0.5315552
#   z: 0.0003868113
# }
# landmark {
#   x: 0.608717
#   y: 0.6999675
#   z: 0.0054688924
# }
# landmark {
#   x: 0.6675862
#   y: 0.6830078
#   z: 0.054147404
# }
# landmark {
#   x: 0.5992959
#   y: 0.5281199
#   z: -0.020693649
# }
# landmark {
#   x: 0.6100006
#   y: 0.74903774
#   z: 0.014977193
# }
# landmark {
#   x: 0.5963613
#   y: 0.56683296
#   z: -0.039860953
# }
# landmark {
#   x: 0.60988677
#   y: 0.5990778
#   z: -0.027125373
# }
# landmark {
#   x: 0.5937392
#   y: 0.75855374
#   z: 0.009105551
# }
# landmark {
#   x: 0.634745
#   y: 0.72059524
#   z: 0.024833998
# }
# landmark {
#   x: 0.62766147
#   y: 0.638813
#   z: -0.0006287393
# }
# landmark {
#   x: 0.6233913
#   y: 0.7364389
#   z: 0.020448342
# }
# landmark {
#   x: 0.65030915
#   y: 0.6364888
#   z: 0.0072231637
# }
# landmark {
#   x: 0.6358791
#   y: 0.6546273
#   z: 0.003652098
# }
# landmark {
#   x: 0.65673906
#   y: 0.6607034
#   z: 0.01937363
# }
# landmark {
#   x: 0.5971747
#   y: 0.7761905
#   z: 0.012134333
# }
# landmark {
#   x: 0.61515164
#   y: 0.6071011
#   z: -0.017442701
# }
# landmark {
#   x: 0.64284384
#   y: 0.7303146
#   z: 0.038541205
# }
# landmark {
#   x: 0.6289728
#   y: 0.74795616
#   z: 0.032053396
# }
# landmark {
#   x: 0.64373016
#   y: 0.7021595
#   z: 0.02539159
# }
# landmark {
#   x: 0.677343
#   y: 0.66360086
#   z: 0.06359769
# }
# landmark {
#   x: 0.6556176
#   y: 0.7018352
#   z: 0.03865508
# }
# landmark {
#   x: 0.67965454
#   y: 0.67279273
#   z: 0.0926878
# }
# landmark {
#   x: 0.6418816
#   y: 0.6752056
#   z: 0.0116563
# }
# landmark {
#   x: 0.6087646
#   y: 0.5842901
#   z: -0.020288892
# }
# landmark {
#   x: 0.60997444
#   y: 0.6312188
#   z: -0.04152579
# }
# landmark {
#   x: 0.615809
#   y: 0.6340764
#   z: -0.028175214
# }
# landmark {
#   x: 0.6065775
#   y: 0.6219574
#   z: -0.050687674
# }
# landmark {
#   x: 0.61755705
#   y: 0.5168436
#   z: -0.008993494
# }
# landmark {
#   x: 0.6365367
#   y: 0.5095476
#   z: -0.009906243
# }
# landmark {
#   x: 0.65210485
#   y: 0.50848037
#   z: -0.0072928327
# }
# landmark {
#   x: 0.6643652
#   y: 0.51053786
#   z: -0.00047414322
# }
# landmark {
#   x: 0.67192775
#   y: 0.5163003
#   z: 0.008381126
# }
# landmark {
#   x: 0.6742332
#   y: 0.54069704
#   z: 0.02886648
# }
# landmark {
#   x: 0.69646394
#   y: 0.5767673
#   z: 0.08782594
# }
# landmark {
#   x: 0.6653961
#   y: 0.56281585
#   z: 0.021046804
# }
# landmark {
#   x: 0.6546604
#   y: 0.5675085
#   z: 0.013262613
# }
# landmark {
#   x: 0.64044636
#   y: 0.56745636
#   z: 0.0072269826
# }
# landmark {
#   x: 0.6268749
#   y: 0.5632926
#   z: 0.0033612952
# }
# landmark {
#   x: 0.6166707
#   y: 0.55759585
#   z: 0.0011029737
# }
# landmark {
#   x: 0.60983086
#   y: 0.5523633
#   z: -0.0008932408
# }
# landmark {
#   x: 0.6918165
#   y: 0.57426584
#   z: 0.13147475
# }
# landmark {
#   x: 0.6145843
#   y: 0.63756275
#   z: -0.022318156
# }
# landmark {
#   x: 0.6036807
#   y: 0.5895468
#   z: -0.03752068
# }
# landmark {
#   x: 0.60312027
#   y: 0.6329145
#   z: -0.051105373
# }
# landmark {
#   x: 0.59602016
#   y: 0.6395135
#   z: -0.04656249
# }
# landmark {
#   x: 0.60231364
#   y: 0.6345498
#   z: -0.045442794
# }
# landmark {
#   x: 0.6108043
#   y: 0.6419113
#   z: -0.018437088
# }
# landmark {
#   x: 0.59436274
#   y: 0.64137316
#   z: -0.049626652
# }
# landmark {
#   x: 0.5923119
#   y: 0.64358175
#   z: -0.03599582
# }
# landmark {
#   x: 0.6105674
#   y: 0.54046786
#   z: 0.0031702165
# }
# landmark {
#   x: 0.6047312
#   y: 0.54406524
#   z: -0.0041730613
# }
# landmark {
#   x: 0.60225844
#   y: 0.5469291
#   z: -0.011953514
# }
# landmark {
#   x: 0.6622596
#   y: 0.535954
#   z: 0.014847086
# }
# landmark {
#   x: 0.6680284
#   y: 0.5294267
#   z: 0.015694203
# }

# %%
#Capture Landmarks & Export to CSV

import csv
import os
import numpy as np

# %%
num_of_coordinates = len(results.face_landmarks.landmark) + len(results.pose_landmarks.landmark)
num_of_coordinates
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_of_coordinates+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val),'v{}'.format(val)]

# %%
landmarks[:-4]
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
 with open('coords.csv', mode='w', newline='') as f: #creating a file to save the coordinates, mode set to write
     csv_writer = csv.writer(f, delimiter=',',quotechar='"',quoting=csv.QUOTE_MINIMAL) 
     csv_writer.writerow(landmarks)

# %%
class_name = "Victorious"

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()

        #Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Make Detection
        results = holistic.process(image) 

        #face_landmarks,pose_landmarks,left_hand_landmarks,right_hand_landmarks

        #Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        #Draw Face Landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(10,110,10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1,circle_radius=1)
                                 )
        
        
        # Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )


        #Exporting the coordinates
        try:
            #Extract Pose Landmarks
            pose = results.pose_landmarks.landmark #Extracting all the landmarks for the pose
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            #Extract Face Landmarks
            face = results.face_landmarks.landmark #Extracting all the landmarks for the face
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            #Concateneting the rows
            row = pose_row+face_row

            #Append class name
            row.insert(0, class_name)

            #Export to CSV
            with open('coords.csv',mode='a',newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"',quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)
            
        except:
            pass
            
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
#Train Custom Model Using Scikit Learn

#Read in Collected Data and process

import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#    class        x1        y1        z1        v1        x2        y2  \
# 0  Happy  0.514410  0.743805 -1.255524  0.999904  0.536797  0.663153
# 1  Happy  0.514406  0.742653 -1.331337  0.999886  0.537401  0.660811
# 2  Happy  0.510174  0.718533 -1.327002  0.999875  0.536499  0.642154
# 3  Happy  0.510229  0.656284 -1.360230  0.999856  0.537452  0.590098
# 4  Happy  0.516246  0.634632 -1.318306  0.999860  0.543659  0.567505
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -1.177978  0.999797  0.556842  ... -0.007433   0.0  0.587250  0.664069
# 1 -1.249990  0.999775  0.557835  ... -0.006480   0.0  0.584010  0.650408
# 2 -1.244843  0.999755  0.557584  ... -0.003298   0.0  0.580914  0.625267
# 3 -1.275419  0.999711  0.558888  ... -0.003450   0.0  0.579659  0.571054
# 4 -1.236367  0.999713  0.563745  ... -0.000713   0.0  0.580834  0.553361
#
#        z500  v500      x501      y501      z501  v501
# 0  0.018185   0.0  0.592507  0.658504  0.018866   0.0
# 1  0.018439   0.0  0.589015  0.645862  0.018954   0.0
# 2  0.019196   0.0  0.586666  0.619208  0.019701   0.0
# 3  0.017489   0.0  0.586218  0.564939  0.018248   0.0
# 4  0.019871   0.0  0.587734  0.546592  0.020662   0.0
#
# [5 rows x 2005 columns]

# %%
df.tail()
# Out:
#           class        x1        y1        z1        v1        x2        y2  \
# 268  Victorious  0.498029  0.727019 -0.876136  0.999654  0.523377  0.670707
# 269  Victorious  0.499138  0.726136 -0.977118  0.999672  0.525226  0.669871
# 270  Victorious  0.499030  0.732212 -1.075877  0.999671  0.525323  0.673178
# 271  Victorious  0.490993  0.732338 -1.058071  0.999505  0.517053  0.672080
# 272  Victorious  0.490308  0.750690 -1.030121  0.999463  0.516618  0.688013
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 268 -0.779294  0.999415  0.537976  ... -0.000266   0.0  0.542159  0.660539
# 269 -0.880428  0.999450  0.539873  ...  0.001236   0.0  0.545215  0.662594
# 270 -0.969840  0.999456  0.540138  ...  0.000681   0.0  0.543994  0.663434
# 271 -0.989272  0.999241  0.534629  ... -0.001122   0.0  0.548109  0.667193
# 272 -0.965343  0.999175  0.534367  ... -0.004893   0.0  0.556989  0.694911
#
#          z500  v500      x501      y501      z501  v501
# 268  0.011806   0.0  0.545928  0.656717  0.012107   0.0
# 269  0.014702   0.0  0.549137  0.659038  0.015109   0.0
# 270  0.013351   0.0  0.547966  0.660039  0.013664   0.0
# 271  0.016092   0.0  0.552193  0.662890  0.016639   0.0
# 272  0.013538   0.0  0.561362  0.690458  0.014083   0.0
#
# [5 rows x 2005 columns]

# %%
df[df['class']=='Sad']
# Out:
#     class        x1        y1        z1        v1        x2        y2  \
# 98    Sad  0.502073  0.864029 -1.438041  0.999332  0.531680  0.785865
# 99    Sad  0.503767  0.858853 -1.418562  0.999251  0.532111  0.783414
# 100   Sad  0.502384  0.850786 -1.431393  0.999169  0.530671  0.775194
# 101   Sad  0.500381  0.848282 -1.400696  0.999062  0.529127  0.773913
# 102   Sad  0.500048  0.847307 -1.359975  0.999067  0.528727  0.773178
# ..    ...       ...       ...       ...       ...       ...       ...
# 198   Sad  0.502724  0.801936 -1.079366  0.999560  0.530450  0.726592
# 199   Sad  0.503991  0.801147 -0.949817  0.999579  0.531855  0.726162
# 200   Sad  0.504018  0.801127 -1.045769  0.999590  0.531859  0.726235
# 201   Sad  0.505879  0.800299 -0.957877  0.999613  0.533222  0.726030
# 202   Sad  0.506193  0.799249 -0.957338  0.999628  0.533353  0.724855
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 98  -1.428385  0.998846  0.552177  ... -0.038426   0.0  0.573560  0.761358
# 99  -1.397784  0.998718  0.552392  ... -0.035691   0.0  0.569967  0.762017
# 100 -1.402308  0.998603  0.551244  ... -0.036369   0.0  0.573332  0.755990
# 101 -1.381478  0.998525  0.549699  ... -0.039430   0.0  0.568810  0.753903
# 102 -1.339151  0.998593  0.549610  ... -0.037124   0.0  0.571809  0.744333
# ..        ...       ...       ...  ...       ...   ...       ...       ...
# 198 -1.064889  0.998879  0.550726  ... -0.034676   0.0  0.572858  0.710720
# 199 -0.939217  0.998928  0.551846  ... -0.034130   0.0  0.568629  0.703033
# 200 -1.030759  0.998958  0.551851  ... -0.031850   0.0  0.565682  0.709057
# 201 -0.942639  0.999018  0.552856  ... -0.034732   0.0  0.575655  0.708447
# 202 -0.940947  0.999058  0.552916  ... -0.034699   0.0  0.572576  0.703870
#
#          z500  v500      x501      y501      z501  v501
# 98  -0.031012   0.0  0.578789  0.750262 -0.031597   0.0
# 99  -0.029076   0.0  0.574632  0.753066 -0.029871   0.0
# 100 -0.026816   0.0  0.578431  0.746395 -0.027383   0.0
# 101 -0.033240   0.0  0.574178  0.742913 -0.034156   0.0
# 102 -0.028937   0.0  0.576743  0.735877 -0.029844   0.0
# ..        ...   ...       ...       ...       ...   ...
# 198 -0.026257   0.0  0.577918  0.702127 -0.026915   0.0
# 199 -0.027196   0.0  0.573003  0.695875 -0.028144   0.0
# 200 -0.025654   0.0  0.569777  0.703354 -0.026646   0.0
# 201 -0.026410   0.0  0.580918  0.699426 -0.027047   0.0
# 202 -0.027429   0.0  0.577073  0.696766 -0.028364   0.0
#
# [105 rows x 2005 columns]

# %%
x = df.drop('class', axis=1) #features
y = df['class'] #target

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 101           Sad
# 157           Sad
# 73          Happy
# 6           Happy
# 239    Victorious
#           ...
# 176           Sad
# 210    Victorious
# 54          Happy
# 155           Sad
# 106           Sad
# Name: class, Length: 82, dtype: object

# %%
#Training the machine learning classification model
from sklearn.pipeline import make_pipeline  #making the ML Pipeline.
from sklearn.preprocessing import StandardScaler #Standardized the data

from sklearn.linear_model import LogisticRegression, RidgeClassifier 
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr' : make_pipeline(StandardScaler(), LogisticRegression()),
    'rc': make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf': make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb': make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
pipelines.keys()
# Out:
# dict_keys(['lr', 'rc', 'rf', 'gb'])

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model =  pipeline.fit(x_train,y_train) #train the model
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['lr'].predict(row)
# Out:
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[259], line 1
# ----> 1 fit_models['lr'].predict(row)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\pipeline.py:602, in Pipeline.predict(self, X, **params)
#     600 if not _routing_enabled():
#     601     for _, name, transform in self._iter(with_final=False):
# --> 602         Xt = transform.transform(Xt)
#     603     return self.steps[-1][1].predict(Xt, **params)
#     605 # metadata routing enabled
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py:273, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     271 @wraps(f)
#     272 def wrapped(self, X, *args, **kwargs):
# --> 273     data_to_wrap = f(self, X, *args, **kwargs)
#     274     if isinstance(data_to_wrap, tuple):
#     275         # only wrap the first output for cross decomposition
#     276         return_tuple = (
#     277             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     278             *data_to_wrap[1:],
#     279         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_data.py:1043, in StandardScaler.transform(self, X, copy)
#    1040 check_is_fitted(self)
#    1042 copy = copy if copy is not None else self.copy
# -> 1043 X = self._validate_data(
#    1044     X,
#    1045     reset=False,
#    1046     accept_sparse="csr",
#    1047     copy=copy,
#    1048     dtype=FLOAT_DTYPES,
#    1049     force_all_finite="allow-nan",
#    1050 )
#    1052 if sparse.issparse(X):
#    1053     if self.with_mean:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:951, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     949         array = xp.astype(array, dtype, copy=False)
#     950     else:
# --> 951         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     952 except ComplexWarning as complex_warning:
#     953     raise ValueError(
#     954         "Complex data not supported\n{}\n".format(array)
#     955     ) from complex_warning
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_array_api.py:521, in _asarray_with_order(array, dtype, order, copy, xp)
#     519     array = numpy.array(array, order=order, dtype=dtype)
#     520 else:
# --> 521     array = numpy.asarray(array, order=order, dtype=dtype)
#     523 # At this point array is a NumPy ndarray. We convert it to an array
#     524 # container that is consistent with the input's namespace.
#     525 return xp.asarray(array)
#
# ValueError: could not convert string to float: 'Victorious'

# %%
from sklearn.metrics import accuracy_score # Accuracy Metrics To Evaluate the model
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(x_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 1.0

# %%
fit_models['rf'].predict(x_test)
# Out:
# array(['Sad', 'Sad', 'Happy', 'Happy', 'Victorious', 'Sad', 'Sad',
#        'Happy', 'Happy', 'Sad', 'Sad', 'Happy', 'Victorious', 'Sad',
#        'Happy', 'Sad', 'Sad', 'Happy', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Victorious', 'Victorious', 'Victorious', 'Happy', 'Happy', 'Sad',
#        'Happy', 'Sad', 'Victorious', 'Happy', 'Happy', 'Happy',
#        'Victorious', 'Sad', 'Victorious', 'Sad', 'Victorious', 'Happy',
#        'Happy', 'Victorious', 'Victorious', 'Sad', 'Sad', 'Sad',
#        'Victorious', 'Happy', 'Happy', 'Happy', 'Happy', 'Sad',
#        'Victorious', 'Sad', 'Happy', 'Happy', 'Sad', 'Victorious', 'Sad',
#        'Happy', 'Sad', 'Sad', 'Sad', 'Happy', 'Victorious', 'Victorious',
#        'Happy', 'Sad', 'Happy', 'Sad', 'Sad', 'Happy', 'Sad', 'Happy',
#        'Happy', 'Happy', 'Sad', 'Sad', 'Victorious', 'Happy', 'Sad',
#        'Sad'], dtype=object)

# %%
y_test
# Out:
# 101           Sad
# 157           Sad
# 73          Happy
# 6           Happy
# 239    Victorious
#           ...
# 176           Sad
# 210    Victorious
# 54          Happy
# 155           Sad
# 106           Sad
# Name: class, Length: 82, dtype: object

# %%
with open('body_language.pkl','wb') as f:
    pickle.dump(fit_models['rf'], f)

# %%
#Making Detection with the Model
with open('body_language.pkl', 'rb') as f: #rb - read binary 
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()

        #Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Make Detection
        results = holistic.process(image) 

        #face_landmarks,pose_landmarks,left_hand_landmarks,right_hand_landmarks

        #Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        #Draw Face Landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS,
                                  mp_drawing.DrawingSpec(color=(110,110,10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1,circle_radius=1)
                                 )
        
        
        # Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )


        #Exporting the coordinates
        try:
            #Extract Pose Landmarks
            pose = results.pose_landmarks.landmark #Extracting all the landmarks for the pose
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            #Extract Face Landmarks
            face = results.face_landmarks.landmark #Extracting all the landmarks for the face
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            #Concateneting the rows
            row = pose_row+face_row

            # #Append class name
            # row.insert(0, class_name)

            # #Export to CSV
            # with open('coords.csv',mode='a',newline='') as f:
            #     csv_writer = csv.writer(f, delimiter=',', quotechar='"',quoting=csv.QUOTE_MINIMAL)
            #     csv_writer.writerow(row)

            X = pd.DataFrame([row])
            body_language_class  = model.predict(X)[0] #Making detections with the class
            body_language_prob = model.predict_proba(X)[0] #Predicting the probability of the partciular class 
            print(body_language_class, body_language_prob)


            #Grab ear coords
            coords = tuple(np.multiply(
                np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, #Grabbing the result value and accesing the pose landmarks coordinates for the left ear 
                          results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y,
                        )), [640,480]).astype(int))    


            
            #Rendering the prediction 
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20,coords[1]-30),
                          (245,117,16),-1)
            cv2.putText(image,body_language_class,coords,
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)


            # Display the probability and the class that is detected
            # Get Status Box
            cv2.rectangle(image, (0,0), (250,60), (245,117,16), -1)
            
            # Display class
            cv2.putText(image, 'CLASS',
                        (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class,  # Corrected typo here
                        (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
            
            # Display probability
            cv2.putText(image, 'PROB',
                        (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)], 2)),  # Corrected typo here
            (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)

        except:
            pass
            
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.81 0.03 0.16]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.77 0.02 0.21]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.78 0.02 0.2 ]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.94 0.   0.06]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.94 0.   0.06]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.89 0.   0.11]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.92 0.   0.08]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.94 0.   0.06]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.9 0.  0.1]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.9 0.  0.1]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.88 0.   0.12]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.86 0.   0.14]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.75 0.04 0.21]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.7  0.04 0.26]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.67 0.04 0.29]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.83 0.01 0.16]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.88 0.   0.12]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.88 0.   0.12]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.88 0.   0.12]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.88 0.   0.12]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.88 0.   0.12]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.88 0.   0.12]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.86 0.   0.14]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.85 0.   0.15]
# Happy [0.89 0.   0.11]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.85 0.   0.15]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.86 0.   0.14]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.86 0.   0.14]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.86 0.   0.14]
# Happy [0.86 0.   0.14]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.84 0.   0.16]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.83 0.   0.17]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.83 0.   0.17]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.78 0.03 0.19]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.74 0.04 0.22]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.78 0.04 0.18]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.8  0.02 0.18]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.8  0.02 0.18]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.79 0.03 0.18]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.81 0.02 0.17]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.75 0.07 0.18]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.71 0.08 0.21]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.58 0.23 0.19]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.63 0.2  0.17]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.72 0.09 0.19]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.6  0.21 0.19]
# Happy [0.61 0.21 0.18]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.5  0.31 0.19]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.52 0.29 0.19]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.5  0.33 0.17]
# Happy [0.47 0.36 0.17]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.55 0.26 0.19]
# Happy [0.63 0.18 0.19]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.71 0.09 0.2 ]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.8  0.02 0.18]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.91 0.   0.09]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.87 0.   0.13]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.86 0.   0.14]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.86 0.   0.14]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.8  0.03 0.17]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.8  0.03 0.17]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.79 0.02 0.19]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.73 0.12 0.15]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.68 0.14 0.18]
# Happy [0.73 0.07 0.2 ]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.79 0.03 0.18]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.83 0.01 0.16]
# Happy [0.73 0.05 0.22]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.72 0.07 0.21]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.63 0.11 0.26]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.64 0.05 0.31]
# Happy [0.69 0.05 0.26]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.63 0.05 0.32]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.72 0.04 0.24]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.66 0.05 0.29]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.67 0.06 0.27]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.71 0.07 0.22]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.66 0.05 0.29]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.75 0.04 0.21]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.66 0.05 0.29]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.03 0.91 0.06]
# Happy [0.4  0.37 0.23]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.77 0.03 0.2 ]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.69 0.03 0.28]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.63 0.03 0.34]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.62 0.07 0.31]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.6 0.1 0.3]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.6  0.07 0.33]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.59 0.09 0.32]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.55 0.17 0.28]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.54 0.19 0.27]
# Happy [0.61 0.1  0.29]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.55 0.18 0.27]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.48 0.21 0.31]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.38 0.33 0.29]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.34 0.39 0.27]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.28 0.37 0.35]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.26 0.43 0.31]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.24 0.4  0.36]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.21 0.49 0.3 ]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.15 0.49 0.36]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.16 0.47 0.37]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.17 0.44 0.39]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.25 0.45 0.3 ]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.53 0.18 0.29]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.68 0.03 0.29]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.7  0.02 0.28]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.7  0.03 0.27]
# ...
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.7  0.03 0.27]
# Happy [0.66 0.03 0.31]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.6  0.04 0.36]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.58 0.06 0.36]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.26 0.35 0.39]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.92 0.08]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.95 0.05]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.95 0.05]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.95 0.05]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.95 0.05]
# Sad [0.   0.95 0.05]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.95 0.05]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.95 0.05]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.95 0.05]
# Sad [0.   0.95 0.05]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.95 0.05]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.94 0.06]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.94 0.06]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.94 0.06]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.94 0.06]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.94 0.06]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.95 0.05]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.95 0.05]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.01 0.94 0.05]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.98 0.02]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.99 0.01]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.99 0.01]
# Sad [0.01 0.97 0.02]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.04 0.91 0.05]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.98 0.02]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.54 0.08 0.38]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.8  0.02 0.18]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.78 0.03 0.19]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.78 0.03 0.19]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.81 0.01 0.18]
# Happy [0.79 0.04 0.17]
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\aqdha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Happy [0.82 0.01 0.17]
